# %% [markdown]
# # Source
#
# - YouTube:
#
#   https://www.youtube.com/watch?v=EpDiyG9_apg&list=PL18h92UN0f0bu-NzcVGeBLVGCGj9hnSha&index=18&ab_channel=LWM-%E0%AE%A4%E0%AE%AE%E0%AE%BF%E0%AE%B4%E0%AF%8D
#
#
# - GitHub:
#
#    https://github.com/learnwithme4998/Data-analysis-and-Data-Analytics

# %% [markdown]
# Distribution Plot
# *   histplot
# *   kdeplot
# *   displot
# *   ecdfplot

# %% [markdown]
# # Distribution Plot

# %% [markdown]
# ## distplot / histplot
# ---------------------
#
# It will works for uni-variant (single variable).
#
# - **distplot** is replaced by **histplot**
# - Jointplot
# - scatter
# - reg
# - resid
# - kde
# - hex

# %%
import seaborn as sns
#import matplotlib.pyplot as plt

# %%
 df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# distplot

sns.distplot(df['total_bill'])
# Out:
# <ipython-input-4-f0f53b027507>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# histplot

sns.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# Kernal Density Estimate:
    # Kde estimates the Probility Density function for values. That means shows in probability percentage instaed of showing real values.

sns.histplot(df['total_bill'], kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# Custom Bins

sns.histplot(df['total_bill'], kde=True, bins=30)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ## Joint Plot
#
# for bivariate (two variables : x, y)

# %%
# Scatter

sns.jointplot(x = 'total_bill', y='tip', data=df)

# %%
# hex
sns.jointplot(x='total_bill', y='tip', data=df, kind='hex', height=5)

# %%
# reg

sns.jointplot(x='total_bill', y='tip', data=df, kind='reg', height=5)

# %%
# pairplot
    #is used to create an individual grpah for all the pairs of numerical columns
sns.pairplot(df)

# %%
# hue
sns.pairplot(df, hue='sex')

# %%
# palette
sns.pairplot(df, hue='sex', palette='coolwarm')

# %%
# rugplot
  # univariate
  # this is the building block fro kde plt

sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
#kde plot
  # This is Keranl Density Estimation plot

sns.kdeplot(df['total_bill'])
sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.rugplot(df['tip'])
sns.kdeplot(df['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
#https://seaborn.pydata.org/generated/seaborn.jointplot.html
